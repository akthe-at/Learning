# %%
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go
df = pd.read_csv('Tweets_Overall.csv')

# %%
df.shape
# Out:
# (17458, 6)

# %%
df.sample(n=10)
# Out:
#                     club                   id                  createdAt  \
# 7870             Arsenal  1522572282920677378  2022-05-06 13:41:34+00:00
# 1180   Manchester United  1579325852042629121  2022-10-10 04:20:00+00:00
# 9098           ChelseaFC  1588606504877162497  2022-11-04 18:58:00+00:00
# 8594             Arsenal  1496934240809852930  2022-02-24 19:45:09+00:00
# 14201            ManCity  1553435936255508480  2022-07-30 17:42:43+00:00
# 6012             Arsenal  1597901881179013120  2022-11-30 10:34:30+00:00
# 437    Manchester United  1590821496079126530  2022-11-10 21:39:35+00:00
# 13959            ManCity  1559632980137607168  2022-08-16 20:07:33+00:00
# 6280             Arsenal  1586723944438140928  2022-10-30 14:17:22+00:00
# 2818   Manchester United  1541746230442590208  2022-06-28 11:32:00+00:00
#
#        favorites  retweets                                               text
# 7870        3174       213  💬 "This is the 𝗱𝗲𝗳𝗶𝗻𝗶𝗻𝗴 𝗺𝗼𝗺𝗲𝗻𝘁 of the season."...
# ...

# %%
df.club.value_counts()
# Out:
# LFC                  3002
# Manchester United    2978
# ChelseaFC            2940
# Arsenal              2887
# SpursOfficial        2830
# ManCity              2821
# Name: club, dtype: int64

# %%
dfLiverpool = df.loc[df['club']=='LFC']
fig = make_subplots(rows=1, cols=1,)
fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], 
    y=dfLiverpool['favorites'],
    name="Liverpool FC Favorites"),row=1, col=1)
fig.update_layout(height=500, width=700,
    title_text="Premier League Twitter Analysis - Favorite Count")
fig.show()

# %%
dfLiverpool = df.loc[df['club']=='LFC']
dfManU = df.loc[df['club']=='Manchester United']
dfArsenal = df.loc[df['club']=='Arsenal']
dfChelsea = df.loc[df['club']=='ChelseaFC']
dfManCity = df.loc[df['club']=='ManCity']
dfSpurs = df.loc[df['club']=='SpursOfficial']

fig = make_subplots(
    rows=6, cols=1
    )

fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], y=dfLiverpool['favorites'],
              name="Liverpool FC Favorites"),
              row=1, col=1)

fig.add_trace(go.Scatter(x=dfManU['createdAt'], y=dfManU['favorites'],
              name="Manchester United Favorites"),
              row=2, col=1)

fig.add_trace(go.Scatter(x=dfArsenal['createdAt'], y=dfArsenal['favorites'],
              name="Arsenal Favorites"),
              row=3, col=1)

fig.add_trace(go.Scatter(x=dfManCity['createdAt'], y=dfManCity['favorites'],
              name="Manchester City Favorites"),
              row=4, col=1)

fig.add_trace(go.Scatter(x=dfSpurs['createdAt'], y=dfSpurs['favorites'],
              name="Tottenham Hotspur Favorites"),
              row=5, col=1)

fig.add_trace(go.Scatter(x=dfChelsea['createdAt'], y=dfChelsea['favorites'],
              name="Chelsea Favorites"),
              row=6, col=1)

fig.update_layout(height=500, width=700,
                  title_text="Premier League Twitter Analysis - Favorite Count")

fig.show()

# %%
df.sort_values('favorites', ascending=False)
# Out:
#                     club                   id                  createdAt  \
# 232    Manchester United  1595107357159297029  2022-11-22 17:30:04+00:00
# 11288          ChelseaFC  1530663553316929539  2022-05-28 21:33:24+00:00
# 5967                 LFC  1530620336915480576  2022-05-28 18:41:40+00:00
# 9983           ChelseaFC  1567438886594281472  2022-09-07 09:05:26+00:00
# 1203   Manchester United  1579183525634650112  2022-10-09 18:54:26+00:00
# ...                  ...                  ...                        ...
# 14699      SpursOfficial  1597558567808155649  2022-11-29 11:50:18+00:00
# 14744      SpursOfficial  1596081269095268352  2022-11-25 10:00:02+00:00
# 17261      SpursOfficial  1517835431466913793  2022-04-23 11:59:01+00:00
# 14738      SpursOfficial  1596175629489053697  2022-11-25 16:15:00+00:00
# 11807            ManCity  1600092663696457728  2022-12-06 11:39:53+00:00
#
#        favorites  retweets                                               text
# ...

# %%
df.loc[df['club']=='ChelseaFC'].sort_values('favorites', ascending=False)
# Out:
#             club                   id                  createdAt  favorites  \
# 11288  ChelseaFC  1530663553316929539  2022-05-28 21:33:24+00:00     349409
# 9983   ChelseaFC  1567438886594281472  2022-09-07 09:05:26+00:00     270128
# 9980   ChelseaFC  1567886827305975808  2022-09-08 14:45:24+00:00     219207
# 10939  ChelseaFC  1547249569565532167  2022-07-13 16:00:18+00:00     213469
# 10573  ChelseaFC  1555512782799396869  2022-08-05 11:15:22+00:00     201437
# ...          ...                  ...                        ...        ...
# 11481  ChelseaFC  1525543054026887170  2022-05-14 18:26:21+00:00       1297
# 11477  ChelseaFC  1525543860679725058  2022-05-14 18:29:34+00:00       1256
# 10768  ChelseaFC  1549922408131346434  2022-07-21 01:01:12+00:00       1195
# 11479  ChelseaFC  1525543431203958786  2022-05-14 18:27:51+00:00       1144
# 11483  ChelseaFC  1525542626732171264  2022-05-14 18:24:40+00:00       1133
#
# ...

# %%
df.loc[df['club']=='LFC'].sort_values('favorites', ascending=False)
# Out:
#      club                   id                  createdAt  favorites  \
# 5967  LFC  1530620336915480576  2022-05-28 18:41:40+00:00     279846
# 5677  LFC  1539569839832023047  2022-06-22 11:23:48+00:00     215955
# 3798  LFC  1581698340567519232  2022-10-16 17:27:25+00:00     145139
# 5918  LFC  1530981279189155840  2022-05-29 18:35:55+00:00     140964
# 5767  LFC  1536770701096624138  2022-06-14 18:01:01+00:00     128287
# ...   ...                  ...                        ...        ...
# 3517  LFC  1586455883898392582  2022-10-29 20:32:12+00:00        672
# 3520  LFC  1586453413558194178  2022-10-29 20:22:23+00:00        657
# 3604  LFC  1585353812893499392  2022-10-26 19:32:58+00:00        629
# 3047  LFC  1597643552061886465  2022-11-29 17:28:00+00:00        601
# 3465  LFC  1587552346145439748  2022-11-01 21:09:09+00:00        598
#
#       retweets                                               text
# 5967     39958                          You'll Never Walk Alone ❤
# ...

# %%
df.loc[df['club']=='Manchester United'].sort_values('favorites', ascending=False)
# Out:
#                    club                   id                  createdAt  \
# 232   Manchester United  1595107357159297029  2022-11-22 17:30:04+00:00
# 1203  Manchester United  1579183525634650112  2022-10-09 18:54:26+00:00
# 2040  Manchester United  1560707140918067201  2022-08-19 19:15:53+00:00
# 1862  Manchester United  1564583777019609088  2022-08-30 12:00:15+00:00
# 1172  Manchester United  1579470190588620800  2022-10-10 13:53:33+00:00
# ...                 ...                  ...                        ...
# 455   Manchester United  1590797302842724378  2022-11-10 20:03:27+00:00
# 259   Manchester United  1594657803209265154  2022-11-21 11:43:42+00:00
# 190   Manchester United  1596144423703756802  2022-11-25 14:11:00+00:00
# 449   Manchester United  1590813166581194754  2022-11-10 21:06:29+00:00
# 0     Manchester United  1600075325718683648  2022-12-06 10:31:00+00:00
#
#       favorites  retweets                                               text
# ...

# %%
df.loc[df['club']=='ManCity'].sort_values('favorites', ascending=False)
# Out:
#           club                   id                  createdAt  favorites  \
# 14501  ManCity  1545815047103844352  2022-07-09 17:00:01+00:00     121619
# 12782  ManCity  1582097115039166464  2022-10-17 19:52:00+00:00     121161
# 11839  ManCity  1599146189936504832  2022-12-03 20:58:57+00:00     120830
# 14515  ManCity  1545331903510859776  2022-07-08 09:00:11+00:00     104158
# 14512  ManCity  1545340458355900418  2022-07-08 09:34:10+00:00      95267
# ...        ...                  ...                        ...        ...
# 11905  ManCity  1597961368925257729  2022-11-30 14:30:53+00:00        370
# 11990  ManCity  1595877414340423680  2022-11-24 20:30:00+00:00        367
# 11866  ManCity  1598674416438845440  2022-12-02 13:44:17+00:00        362
# 11941  ManCity  1597213722346504193  2022-11-28 13:00:00+00:00        330
# 11807  ManCity  1600092663696457728  2022-12-06 11:39:53+00:00        111
#
#        retweets                                               text
# ...

# %%
df.loc[df['club']=='Arsenal'].sort_values('favorites', ascending=False)
# Out:
#          club                   id                  createdAt  favorites  \
# 7371  Arsenal  1550526088190861313  2022-07-22 17:00:01+00:00     213115
# 7555  Arsenal  1543863208569708544  2022-07-04 07:44:07+00:00     183418
# 6557  Arsenal  1579162432764723200  2022-10-09 17:30:38+00:00     170536
# 7550  Arsenal  1543925323175268353  2022-07-04 11:50:56+00:00     169204
# 6556  Arsenal  1579164240463552512  2022-10-09 17:37:49+00:00     160184
# ...       ...                  ...                        ...        ...
# 8222  Arsenal  1511048457854849024  2022-04-04 18:30:00+00:00        696
# 8738  Arsenal  1491853464040787970  2022-02-10 19:15:57+00:00        688
# 8157  Arsenal  1512809252926205961  2022-04-09 15:06:47+00:00        625
# 8215  Arsenal  1511071985333420043  2022-04-04 20:03:30+00:00        597
# 8164  Arsenal  1512787419241889792  2022-04-09 13:40:01+00:00        548
#
#       retweets                                               text
# ...

# %%
df.loc[df['club']=='SpursOfficial'].sort_values('favorites', ascending=False)
# Out:
#                 club                   id                  createdAt  \
# 16847  SpursOfficial  1528420824591523843  2022-05-22 17:01:35+00:00
# 17131  SpursOfficial  1521600988318162945  2022-05-03 21:22:00+00:00
# 14666  SpursOfficial  1598726658046959616  2022-12-02 17:11:52+00:00
# 14748  SpursOfficial  1595895533754671104  2022-11-24 21:42:00+00:00
# 16843  SpursOfficial  1528448858342162434  2022-05-22 18:52:59+00:00
# ...              ...                  ...                        ...
# 15134  SpursOfficial  1585341239095853066  2022-10-26 18:43:00+00:00
# 14699  SpursOfficial  1597558567808155649  2022-11-29 11:50:18+00:00
# 14744  SpursOfficial  1596081269095268352  2022-11-25 10:00:02+00:00
# 17261  SpursOfficial  1517835431466913793  2022-04-23 11:59:01+00:00
# 14738  SpursOfficial  1596175629489053697  2022-11-25 16:15:00+00:00
#
#        favorites  retweets                                               text
# ...

# %%
dfLiverpool = df.loc[df['club']=='LFC']
dfManU = df.loc[df['club']=='Manchester United']
dfArsenal = df.loc[df['club']=='Arsenal']
dfChelsea = df.loc[df['club']=='ChelseaFC']
dfManCity = df.loc[df['club']=='ManCity']
dfSpurs = df.loc[df['club']=='SpursOfficial']

# %%
fig = make_subplots(
    rows=6, cols=1
    )

fig.add_trace(go.Scatter(x=dfLiverpool['createdAt'], y=dfLiverpool['retweets'],
              name="Liverpool FC Retweets"),
              row=1, col=1)

fig.add_trace(go.Scatter(x=dfManU['createdAt'], y=dfManU['retweets'],
              name="Manchester United Retweets"),
              row=2, col=1)

fig.add_trace(go.Scatter(x=dfArsenal['createdAt'], y=dfArsenal['retweets'],
              name="Arsenal Retweets"),
              row=3, col=1)

fig.add_trace(go.Scatter(x=dfManCity['createdAt'], y=dfManCity['retweets'],
              name="Manchester City Retweets"),
              row=4, col=1)

fig.add_trace(go.Scatter(x=dfSpurs['createdAt'], y=dfSpurs['retweets'],
              name="Tottenham Hotspur Retweets"),
              row=5, col=1)

fig.add_trace(go.Scatter(x=dfChelsea['createdAt'], y=dfChelsea['retweets'],
              name="Chelsea Retweets"),
              row=6, col=1)

fig.update_layout(height=500, width=700,
                  title_text="Premier League Twitter Analysis - Retweet Count")

fig.show()

# %%
dfLiverpool.sort_values('retweets', ascending=False)
# Out:
#      club                   id                  createdAt  favorites  \
# 5967  LFC  1530620336915480576  2022-05-28 18:41:40+00:00     279846
# 3798  LFC  1581698340567519232  2022-10-16 17:27:25+00:00     145139
# 4087  LFC  1576480449441894400  2022-10-02 07:53:23+00:00      93790
# 5769  LFC  1536769450720075776  2022-06-14 17:56:03+00:00     104252
# 5677  LFC  1539569839832023047  2022-06-22 11:23:48+00:00     215955
# ...   ...                  ...                        ...        ...
# 5008  LFC  1553831398603202561  2022-07-31 19:54:08+00:00        934
# 5007  LFC  1553833911477833728  2022-07-31 20:04:07+00:00        791
# 5016  LFC  1553813650338619393  2022-07-31 18:43:37+00:00       1011
# 3307  LFC  1590451570197819394  2022-11-09 21:09:38+00:00        681
# 3047  LFC  1597643552061886465  2022-11-29 17:28:00+00:00        601
#
#       retweets                                               text
# 5967     39958                          You'll Never Walk Alone ❤
# ...

# %%
dfManU.sort_values('retweets', ascending=False)
# Out:
#                    club                   id                  createdAt  \
# 232   Manchester United  1595107357159297029  2022-11-22 17:30:04+00:00
# 2040  Manchester United  1560707140918067201  2022-08-19 19:15:53+00:00
# 1357  Manchester United  1576475334811480064  2022-10-02 07:33:03+00:00
# 2558  Manchester United  1547944083800223745  2022-07-15 14:00:03+00:00
# 1862  Manchester United  1564583777019609088  2022-08-30 12:00:15+00:00
# ...                 ...                  ...                        ...
# 254   Manchester United  1594693344076210179  2022-11-21 14:04:55+00:00
# 20    Manchester United  1599746987900870656  2022-12-05 12:46:18+00:00
# 133   Manchester United  1597363204832870401  2022-11-28 22:54:00+00:00
# 1461  Manchester United  1573689789030834180  2022-09-24 15:04:18+00:00
# 0     Manchester United  1600075325718683648  2022-12-06 10:31:00+00:00
#
#       favorites  retweets                                               text
# ...

# %%
dfChelsea.sort_values('retweets', ascending=False)
# Out:
#             club                   id                  createdAt  favorites  \
# 9983   ChelseaFC  1567438886594281472  2022-09-07 09:05:26+00:00     270128
# 11288  ChelseaFC  1530663553316929539  2022-05-28 21:33:24+00:00     349409
# 9980   ChelseaFC  1567886827305975808  2022-09-08 14:45:24+00:00     219207
# 10939  ChelseaFC  1547249569565532167  2022-07-13 16:00:18+00:00     213469
# 10573  ChelseaFC  1555512782799396869  2022-08-05 11:15:22+00:00     201437
# ...          ...                  ...                        ...        ...
# 10768  ChelseaFC  1549922408131346434  2022-07-21 01:01:12+00:00       1195
# 11739  ChelseaFC  1520776937710444549  2022-05-01 14:47:31+00:00       1498
# 10744  ChelseaFC  1549946929265655808  2022-07-21 02:38:39+00:00       1534
# 10746  ChelseaFC  1549946491837550592  2022-07-21 02:36:54+00:00       1396
# 10748  ChelseaFC  1549946152535162880  2022-07-21 02:35:34+00:00       1377
#
# ...

# %%
dfArsenal.sort_values('retweets', ascending=False)
# Out:
#          club                   id                  createdAt  favorites  \
# 6557  Arsenal  1579162432764723200  2022-10-09 17:30:38+00:00     170536
# 7555  Arsenal  1543863208569708544  2022-07-04 07:44:07+00:00     183418
# 7371  Arsenal  1550526088190861313  2022-07-22 17:00:01+00:00     213115
# 6182  Arsenal  1589254739824611328  2022-11-06 13:53:51+00:00     124727
# 6556  Arsenal  1579164240463552512  2022-10-09 17:37:49+00:00     160184
# ...       ...                  ...                        ...        ...
# 8164  Arsenal  1512787419241889792  2022-04-09 13:40:01+00:00        548
# 8211  Arsenal  1511077974367518721  2022-04-04 20:27:18+00:00       1172
# 8860  Arsenal  1485248298793512963  2022-01-23 13:49:23+00:00        736
# 6314  Arsenal  1585689601208946689  2022-10-27 17:47:16+00:00        746
# 8738  Arsenal  1491853464040787970  2022-02-10 19:15:57+00:00        688
#
#       retweets                                               text
# ...

# %%
dfManCity.sort_values('retweets', ascending=False)
# Out:
#           club                   id                  createdAt  favorites  \
# 12782  ManCity  1582097115039166464  2022-10-17 19:52:00+00:00     121161
# 13205  ManCity  1576476461724098561  2022-10-02 07:37:32+00:00      61166
# 14515  ManCity  1545331903510859776  2022-07-08 09:00:11+00:00     104158
# 13164  ManCity  1576585447211667461  2022-10-02 14:50:36+00:00      49466
# 14559  ManCity  1543881834366439426  2022-07-04 08:58:07+00:00      48696
# ...        ...                  ...                        ...        ...
# 12439  ManCity  1587909861601267712  2022-11-02 20:49:47+00:00        428
# 13293  ManCity  1574697772888260609  2022-09-27 09:49:40+00:00        512
# 11905  ManCity  1597961368925257729  2022-11-30 14:30:53+00:00        370
# 11873  ManCity  1598628409235722240  2022-12-02 10:41:28+00:00        374
# 11807  ManCity  1600092663696457728  2022-12-06 11:39:53+00:00        111
#
#        retweets                                               text
# ...

# %%
dfSpurs.sort_values('retweets', ascending=False)
# Out:
#                 club                   id                  createdAt  \
# 16847  SpursOfficial  1528420824591523843  2022-05-22 17:01:35+00:00
# 14666  SpursOfficial  1598726658046959616  2022-12-02 17:11:52+00:00
# 16848  SpursOfficial  1528417734677221379  2022-05-22 16:49:19+00:00
# 16850  SpursOfficial  1528413984688422912  2022-05-22 16:34:25+00:00
# 16843  SpursOfficial  1528448858342162434  2022-05-22 18:52:59+00:00
# ...              ...                  ...                        ...
# 15134  SpursOfficial  1585341239095853066  2022-10-26 18:43:00+00:00
# 14801  SpursOfficial  1593891839412555776  2022-11-19 09:00:02+00:00
# 14734  SpursOfficial  1596474068340989953  2022-11-26 12:00:53+00:00
# 17261  SpursOfficial  1517835431466913793  2022-04-23 11:59:01+00:00
# 14696  SpursOfficial  1597578263756525568  2022-11-29 13:08:34+00:00
#
#        favorites  retweets                                               text
# ...
